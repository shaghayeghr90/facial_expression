# %%
from mario_dataset_utils import *

# %%
inpainting_signal('vgg_lstm_predictions',7)
# Out:
# _dit_22_02_1_A
# normalized_expressions:  (771, 7)
# _dit_22_02_1_B
# normalized_expressions:  (1411, 7)
# _teo_10_03_1_A
# normalized_expressions:  (1680, 7)
# ama_16_03_1_A
# normalized_expressions:  (588, 7)
# ama_16_03_1_B
# normalized_expressions:  (2023, 7)
# ant_23_03_1_B
# normalized_expressions:  (1267, 7)
# asi_08_02_1_A
# normalized_expressions:  (1144, 7)
# asi_08_02_1_B
# normalized_expressions:  (1067, 7)
# ben_23_03_1_A
# normalized_expressions:  (2027, 7)
# ben_23_03_1_B
# normalized_expressions:  (1381, 7)
# chr_22_03_1_A
# normalized_expressions:  (2914, 7)
# chr_22_03_1_B
# normalized_expressions:  (1015, 7)
# cla_22_03_1_A
# normalized_expressions:  (1532, 7)
# cla_22_03_1_B
# normalized_expressions:  (914, 7)
# dan_17_11_1_A
# normalized_expressions:  (2109, 7)
# dan_17_11_1_B
# normalized_expressions:  (1862, 7)
# dar_22_03_1_A
# normalized_expressions:  (3121, 7)
# dar_22_03_1_B
# normalized_expressions:  (1194, 7)
# des_16_03_1_A
# ...

# %%
#vgg_lstm_filter_signal
filter_signal('vgg_lstm_predictions',7,15)
# Out:
# _dit_22_02_1_A
# signals:  (771, 7)
# filtered_signal:  (7, 771)
# _dit_22_02_1_B
# signals:  (1411, 7)
# filtered_signal:  (7, 1411)
# _teo_10_03_1_A
# signals:  (1680, 7)
# filtered_signal:  (7, 1680)
# ama_16_03_1_A
# signals:  (588, 7)
# filtered_signal:  (7, 588)
# ama_16_03_1_B
# signals:  (2023, 7)
# filtered_signal:  (7, 2023)
# ant_23_03_1_B
# signals:  (1267, 7)
# filtered_signal:  (7, 1267)
# asi_08_02_1_A
# signals:  (1144, 7)
# filtered_signal:  (7, 1144)
# asi_08_02_1_B
# signals:  (1067, 7)
# filtered_signal:  (7, 1067)
# ben_23_03_1_A
# signals:  (2027, 7)
# filtered_signal:  (7, 2027)
# ben_23_03_1_B
# signals:  (1381, 7)
# filtered_signal:  (7, 1381)
# chr_22_03_1_A
# signals:  (2914, 7)
# filtered_signal:  (7, 2914)
# chr_22_03_1_B
# signals:  (1015, 7)
# filtered_signal:  (7, 1015)
# cla_22_03_1_A
# signals:  (1532, 7)
# filtered_signal:  (7, 1532)
# cla_22_03_1_B
# signals:  (914, 7)
# filtered_signal:  (7, 914)
# dan_17_11_1_A
# signals:  (2109, 7)
# ...

# %%
#vgg_lstm_per_player
save_affect_per_player_per_event('vgg_lstm_per_player','vgg_lstm_per_player',7,15,30,'vgg_lstm_predictions',False)
# Out:
# /home/Shr147896325/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
save_plots_3(3,3,True,15,60,7,'average_around_event','vgg_lstm_plots','vgg_lstm_predictions',False)
